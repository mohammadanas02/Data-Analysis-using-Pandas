# %%
import pandas as pd

# %%
df = pd.read_csv('V5.csv')

# %%
df.shape
# Out:
# (10000, 12)

# %%
# prompt: How many unknown ("?) values are present in the dataset? Remove/Delete unknown ("?) values present in the dataset to make it null value.
# Remove/Delete - means it will show NAN in place of "?"
# Note: If there is no value present in the dataset it is represented as NAN(read pandas documentation for all the other ways to represent null values) in data

import pandas as pd
df.replace('?', pd.NA, inplace=True)
print(df.isnull().sum().sum())
# Out:
# 5548

# %%
df.shape
# Out:
# (10000, 12)

# %%
df.head(2)
# Out:
#          Date  Year    Locality  Estimated Value  Sale Price       Property  \
# 0  2009-01-02  2009   Waterbury         111440.0    185000.0  Single Family
# 1  2009-01-02  2009  Bridgeport         124670.0    150000.0     Two Family
#
#       Residential  num_rooms  num_bathrooms  carpet_area  property_tax_rate  \
# 0  Detached House          3              3        996.0           1.025953
# 1          Duplex          4              3       1241.0           1.025953
#
#     Face
# 0  South
# 1  South

# %%
df.iloc[692,0]
# Out:
# '2009-11-16'

# %%
df.iloc[546,7]
# Out:
# 3

# %%
df['Locality'].unique()
# Out:
# array(['Waterbury', 'Bridgeport', 'Greenwich', 'Norwalk', nan,
#        'Fairfield', 'West Hartford', 'Stamford'], dtype=object)

# %%
# prompt: What are the unique values present in the Locality feature of the dataset?

print(df['Locality'].unique())
# Out:
# ['Waterbury' 'Bridgeport' 'Greenwich' 'Norwalk' nan 'Fairfield'
#  'West Hartford' 'Stamford']

# %%
df['Locality'].isnull().sum()
# Out:
# 1253

# %%
df['property_tax_rate'].isnull().sum()
# Out:
# 0

# %%
# prompt: Which of the following features have missing(NaN) values present in the dataset?

for column in df.columns:
  if df[column].isnull().any():
    print(column)
# Out:
# Locality
# Estimated Value
# Property
# carpet_area

# %%
for coloumn in df.columns:
  a = df[coloumn].isnull().sum()
  print(coloumn, a)
# Out:
# Date 0
# Year 0
# Locality 1253
# Estimated Value 1243
# Sale Price 0
# Property 1823
# Residential 0
# num_rooms 0
# num_bathrooms 0
# carpet_area 1229
# property_tax_rate 0
# Face 0

# %%
# prompt: Drop all the samples(rows) with missing values strictly greater than 2. How many samples remains after that ?

import pandas as pd

# Assuming df is already defined and loaded with your data

df_cleaned = df.dropna(thresh=df.shape[1] - 2)

print(df_cleaned.shape[0])
# Out:
# 9917

# %%
# prompt: Drop all the samples(rows) with missing values in the original dataframe. How many samples remains after that ?

df_dropped = df.dropna()
print(df_dropped.shape[0])
# Out:
# 5449

# %%
# prompt: Drop all the samples(rows) with missing values strictly greater than 2. How many samples remains after that ?
#  (Note: compute after removing "?")

import pandas as pd
# Assuming df is already defined and loaded with your data and '?' replaced with pd.NA

df_cleaned = df.dropna(thresh=df.shape[1] - 2)

print(df_cleaned.shape[0])
# Out:
# 9917
